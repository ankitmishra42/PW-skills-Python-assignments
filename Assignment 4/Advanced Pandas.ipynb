# %% [markdown]
# ### Advanced Pandas

# %% [markdown]
# **Q1 Dataset Exploration**<br>
# Perform the following exploratory steps:
# - Display the first 10 rows
# - Display the dataset structure using info()
# - Find the number of rows and columns
# - Identify the data types of each column

# %%
import pandas as pd

df = pd.read_csv("Advanced_pandas_sales_dataset.csv")

# Display the first 10 rows
df.head(10)
# Out:
#    Order_ID  Order_Date Customer       City Region   Product     Category  \
# 0      1001  2024-10-01    Priya  Hyderabad   East     Mouse  Accessories
# 1      1002  2024-05-03    Sneha    Kolkata   East   Monitor  Electronics
# 2      1003  2024-01-26    Anita     Mumbai   West     Phone  Electronics
# 3      1004  2024-06-06     Sara       Pune   East  Keyboard  Accessories
# 4      1005  2024-10-15    Rahul  Bangalore  South   Monitor  Electronics
# 5      1006  2024-07-04    Pooja  Bangalore   West   Printer       Office
# 6      1007  2024-06-24      Dev    Chennai   East   Monitor  Electronics
# 7      1008  2024-03-18    Kavya    Kolkata   East     Phone  Electronics
# 8      1009  2024-10-31    Kavya  Ahmedabad   East     Phone  Electronics
# 9      1010  2024-12-25    Pooja  Ahmedabad  North     Phone  Electronics
#
#    Sales  Quantity  Discount  Profit
# 0   1735         7      0.00  307.52
# 1    807         2      0.15   49.89
# 2   2328         1      0.20   66.47
# ...

# %%
# Display the dataset structure using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_ID    230 non-null    int64
#  1   Order_Date  230 non-null    object
#  2   Customer    230 non-null    object
#  3   City        230 non-null    object
#  4   Region      230 non-null    object
#  5   Product     230 non-null    object
#  6   Category    230 non-null    object
#  7   Sales       230 non-null    int64
#  8   Quantity    230 non-null    int64
#  9   Discount    230 non-null    float64
#  10  Profit      230 non-null    float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 19.9+ KB

# %%
# Find the number of rows and columns
print(df.shape, "\n")

# Identify the data types of each column
df.dtypes
# Out:
# (230, 11)
# Order_ID        int64
# Order_Date     object
# Customer       object
# City           object
# Region         object
# Product        object
# Category       object
# Sales           int64
# Quantity        int64
# Discount      float64
# Profit        float64
# dtype: object

# %% [markdown]
# **Q2 Sales Filtering Analysis, Filter the dataset to display:**
# - Orders where Sales > 3500
# - Orders where Region = "East" and Sales > 2500
# - Explain what insights you observe.

# %%
# Orders where Sales > 3500
df[df['Sales'] > 3500]

# df[df.Sales > 3500]
# Out:
#      Order_ID  Order_Date Customer       City Region   Product     Category  \
# 3        1004  2024-06-06     Sara       Pune   East  Keyboard  Accessories
# 4        1005  2024-10-15    Rahul  Bangalore  South   Monitor  Electronics
# 7        1008  2024-03-18    Kavya    Kolkata   East     Phone  Electronics
# 8        1009  2024-10-31    Kavya  Ahmedabad   East     Phone  Electronics
# 10       1011  2024-06-30     Neha      Delhi  South   Printer       Office
# ..        ...         ...      ...        ...    ...       ...          ...
# 219      1220  2024-03-22    Meera  Bangalore   West     Phone  Electronics
# 222      1223  2024-03-04    Meera  Ahmedabad  South     Phone  Electronics
# 223      1224  2024-01-07      Dev  Bangalore   East    Tablet  Electronics
# 225      1226  2024-06-14    Anita  Ahmedabad   East    Laptop  Electronics
# 229      1230  2024-04-13    Meera    Kolkata  North   Monitor  Electronics
#
#      Sales  Quantity  Discount   Profit
# ...

# %%
# Orders where Region = "East" and Sales > 2500
df[(df.Region == "East") & (df.Sales > 2500)]
# Out:
#      Order_ID  Order_Date Customer       City Region     Product     Category  \
# 3        1004  2024-06-06     Sara       Pune   East    Keyboard  Accessories
# 7        1008  2024-03-18    Kavya    Kolkata   East       Phone  Electronics
# 8        1009  2024-10-31    Kavya  Ahmedabad   East       Phone  Electronics
# 13       1014  2024-03-18    Anita  Bangalore   East       Mouse  Accessories
# 21       1022  2024-01-14    Nitin    Chennai   East     Monitor  Electronics
# 27       1028  2024-07-21      Dev    Kolkata   East      Tablet  Electronics
# 33       1034  2024-12-15    Nitin  Ahmedabad   East      Tablet  Electronics
# 34       1035  2024-02-20    Nitin  Ahmedabad   East      Laptop  Electronics
# 41       1042  2024-07-15    Rohan    Chennai   East      Laptop  Electronics
# 43       1044  2024-09-20    Kavya  Hyderabad   East     Printer       Office
# 52       1053  2024-05-24    Anita    Chennai   East       Phone  Electronics
# ...

# %% [markdown]
# Explain what insights you observe.
# - Electronics drives sales, especially in the East
# - High sales not means high profit due to heavy discounts (up to 20%)
# - Few loyal customers generate most high-value purchases

# %% [markdown]
# **Q3 Customer Purchase Analysis**
# - Identify the top 5 customers based on total sales.
# - Hint: Use GroupBy with aggregation.

# %%
df.groupby('Customer')['Sales'].sum().nlargest(5).reset_index()
# Out:
#   Customer  Sales
# 0    Nitin  59820
# 1      Raj  58416
# 2    Rahul  52291
# 3      Dev  48500
# 4     Isha  46818

# %% [markdown]
# **Q4 Regional Sales Performance**
# - Calculate the total sales generated by each region.
# - Then identify:
#   - Which region generated the highest revenue?

# %%
# Calculate the total sales generated by each region.
salesByRegion = df.groupby('Region')['Sales'].sum().reset_index()
print(salesByRegion)

# Which region generated the highest revenue?
topRevenue = salesByRegion[salesByRegion["Sales"] == salesByRegion["Sales"].max()]
topRevenue
# Out:
#   Region   Sales
# 0   East  232675
# 1  North  158210
# 2  South  183108
# 3   West  170227
#   Region   Sales
# 0   East  232675

# %% [markdown]
# **Q5 Product Performance Analysis**
# - Calculate the total quantity sold for each product.
# - Which product appears to be the most popular?

# %%
# Calculate the total quantity sold for each product.
quantityByProduct = df.groupby('Product')['Quantity'].sum().reset_index()
print(quantityByProduct)

# Which product appears to be the most popular?
mostPopular = quantityByProduct[quantityByProduct["Quantity"] == quantityByProduct["Quantity"].max()]
mostPopular
# Out:
#       Product  Quantity
# 0  Headphones       115
# 1    Keyboard       110
# 2      Laptop       140
# 3     Monitor       156
# 4       Mouse       122
# 5       Phone       151
# 6     Printer       108
# 7      Tablet       150
#    Product  Quantity
# 3  Monitor       156

# %% [markdown]
# **Q6 Multi-Level Grouping**
# - Group the dataset by: Region and Category
# - Calculate the total sales for each combination.
# - What insights can you derive from this analysis?

# %%
# Group the dataset by: Region and Category
# Calculate the total sales for each combination.
df.groupby(['Region', 'Category'])['Sales'].sum().unstack()
# Out:
# Category  Accessories  Electronics  Office
# Region
# East            57646       160907   14122
# North           62052        70023   26135
# South           80914        86690   15504
# West            64811        84128   21288

# %% [markdown]
# What insights can you derive from this analysis?
# - Discount Trap: High discounts on big orders reduce profit; some even cause losses
# - Price > Volume: High sales come from expensive products, not bulk buying
# - East Region Focus: Ahmedabad & Chennai lead; Pune & Hyderabad have growth potential
# - Product Strategy: Electronics dominate; Office items need bundling to boost value
# - Loyal Customers: Few repeat buyers drive major revenue opportunity for loyalty programs

# %% [markdown]
# **Q7 Pivot Table Creation**<br>
# Create a pivot table showing:
# - Rows → Region
# - Columns → Product
# - Values → Total Sales
# - Which region sells the most laptops?

# %%
pivot_table = df.pivot_table(index='Region', 
                             columns='Product', 
                             values='Sales', 
                             aggfunc='sum', 
                             fill_value=0)

print(pivot_table)
print(f"\nThe region that sells the most laptops is: {pivot_table['Laptop'].idxmax()}")
# Out:
# Product  Headphones  Keyboard  Laptop  Monitor  Mouse  Phone  Printer  Tablet
# Region
# East          23899     10845   55568    31299  22902  39667    14122   34373
# North         15450     20538    4540    14922  26064  30535    26135   20026
# South         24111     23480   23029    19167  33323  18218    15504   26276
# West          17159     38499   10826    18178   9153  27850    21288   27274
#
# The region that sells the most laptops is: East

# %% [markdown]
# **Q8 Profitability Analysis**
# - Calculate the average profit for each product category.
# - Which category is most profitable?

# %%
# Calculate the average profit for each product category.
avgProfitByCategory = df.groupby('Category')['Profit'].mean().reset_index()
print(avgProfitByCategory)

# Which category is most profitable?
topAvgProfitByCategory = df.groupby('Category')['Profit'].mean().idxmax()
print(f"\n{topAvgProfitByCategory} category is most profitable")
# Out:
#       Category      Profit
# 0  Accessories  410.603086
# 1  Electronics  396.462114
# 2       Office  471.938462
#
# Office category is most profitable

# %% [markdown]
# **Q9 Discount Impact Study, Analyze the relationship between discount and profit.**<br>
# Tasks:
# - Calculate the average profit for each discount level
# - Identify whether higher discounts lead to lower profit

# %%
# Calculate the average profit for each discount level
avgProfitByDiscountLevel = df.groupby('Discount')['Profit'].mean().reset_index()
print(avgProfitByDiscountLevel,'\n')

# Identify whether higher discounts lead to lower profit
correlation = df['Discount'].corr(df['Profit'])
if correlation < 0 :
    print('Yes higher discounts leads to lower profit')
else :
    print('No higher discounts does not lead to lower profit')
# Out:
#    Discount      Profit
# 0      0.00  751.210588
# 1      0.05  531.368039
# 2      0.10  346.460513
# 3      0.15  237.191400
# 4      0.20   90.026923
#
# Yes higher discounts leads to lower profit

# %% [markdown]
# **Q10 End-to-End Data Wrangling Task**<br>
# Perform the following workflow:
# - Filter the dataset where Sales > 3000
# - Group data by Region and Product
# - Calculate total sales
# - Reshape the result into a pivot table
# - Explain the business insights obtained from this analysis.

# %%
# Filter the dataset where Sales > 3000
higherSalesdf = df[df['Sales'] > 3000]

# Group data by Region and Product
# Calculate total sales
# Reshape the result into a pivot table
pivot_result = higherSalesdf.pivot_table(index='Region', 
                                         columns='Product', 
                                         values='Sales', 
                                         aggfunc='sum', 
                                         fill_value=0)

pivot_result
# Out:
# Product  Headphones  Keyboard  Laptop  Monitor  Mouse  Phone  Printer  Tablet
# Region
# East          14469      9642   44096    16420  19000  29500     3696   29229
# North          5326     15653    4540     5087  22209  24670    17185    3392
# South         10026     19249   17950    14921  26928  18218    14143   19613
# West          13898     33380    5922    14354   3511  15653    12648   17185

# %% [markdown]
# Explain the business insights obtained from this analysis.
# - Discount vs Profit: Heavy discounts on big orders hurt margins, some sales even become losses
# - Electronics Lead: High-value sales mainly come from expensive electronics (laptops, phones, etc.)
# - City Focus: Ahmedabad, Chennai, Kolkata drive most high-ticket sales in the East
# - Top Customers Matter: Few buyers generate most revenue target with VIP programs
# - Price over Quantity: Sales growth comes from expensive items, not more items focus on upselling
